# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
toplam_urun , toplam_yorum = 0 , 0
yorum_listesi = []
urun_listesi = []
import csv
liste = []
ggg = pd.DataFrame({'Puan' : [] , 'Yorumlar' : []})
xx = pd.DataFrame({'Puan' : [], 'Puana Göre Sonuç' : [], 'Türkçe Yorum' : []})

yildiz_sayisi = []
sonuc = []

# %%
xx = pd.DataFrame({'Puan' : [], 'Puana Göre Sonuç' : [], 'Türkçe Yorum' : []})
yy = pd.DataFrame({'Puan' : [], 'Puana Göre Sonuç' : [], 'Türkçe Yorum' : []})

# %%
#@title Varsayılan başlık metni
for sayfa_sayisi in range(25,30):
  url = "https://www.hepsiburada.com/cep-telefonlari-c-371965" + "?sayfa=" + str(sayfa_sayisi)
  print("{}. Sayfa İnceleniyor...".format(sayfa_sayisi))
  r = requests.get(url)
  r.status_code
  r.content
  soup = BeautifulSoup(r.content , "lxml")
  urunler = soup.findAll("li" , attrs = {"class" : "productListContent-zAP0Y5msy8OHn5z7T_K_"})
  link_basi = "https://www.hepsiburada.com"
  for urun in urunler:
    link_sonu = urun.a.get("href")
    link = link_basi + link_sonu + "-yorumlari?sirala=clap&sayfa=1"
    link_isim = urun.a.get("title")

    try:
      urun_r = requests.get(link)
    except:
      print("Connection refused by the server..")
      print("Let me sleep for 5 seconds")
      print("ZZzzzz...")
      time.sleep(1)
      print("Was a nice sleep, now let me continue...")
      continue
    urun_soup = BeautifulSoup(urun_r.content , "lxml")



    yildizlar = urun_soup.find_all("div" , attrs = {"class" , "hermes-ReviewCard-module-dY_oaYMIo0DJcUiSeaVW"})
    for yildiz in yildizlar:
      sayi = yildiz.find("div" , attrs = {"class" : "hermes-RatingPointer-module-UefD0t2XvgGWsKdLkNoX"}).find_all(class_= "star")
      #xx['Puan'] = xx['Puan'].append(len(sayi), ignore_index=True)
      yildiz_sayisi.append(len(sayi))
      print(len(sayi))
      #time.sleep(1)


    #urun_soup = BeautifulSoup(urun_r.content , "lxml")


    #urun_adi = urun_soup.find("div" , attrs = {"class" : "product-information"}).find("header").find("h1").text

    toplam_urun +=1
    #str_urun_adi = str(urun_adi)
    #urun_listesi.append(urun_adi)

    yorumlar = urun_soup.find_all("div" , attrs = {"class" , "hermes-ReviewCard-module-dY_oaYMIo0DJcUiSeaVW"})
    #yorumlar_ic = yorumlar.find("div" , attrs = {"itemprop" , "review"})
    for yorum in yorumlar:
      y1 = yorum.find("div" , attrs = {"class" : "hermes-ReviewCard-module-KaU17BbDowCWcTZ9zzxw"}).find("span").text
      #print(urun_adi)
      print(y1)
      print("#"*10)
      #liste_icin_yorum = yorum.find("div" , attrs = {"class" : "hermes-ReviewCard-module-KaU17BbDowCWcTZ9zzxw"}).find("span").text
      toplam_yorum +=1
      #liste.append(y1)
      #liste.append(urun_adi)
      yorum_listesi.append(y1)
      #urun_listesi.append(urun_adi)
      #xx['Yorumlar'] = xx['Yorumlar'].append(y1, ignore_index=True)



      #str_yorum = str(yorum)
      #yorum_listesi.append(yorum.find("div" , attrs = {"class" : "hermes-ReviewCard-module-KaU17BbDowCWcTZ9zzxw"}).find("span").text)

      #time.sleep(100)

print("Toplam ürün sayısı : {} \nToplam yorum sayısı : {}" . format(toplam_urun,toplam_yorum))
# Out:
# 25. Sayfa İnceleniyor...
# 26. Sayfa İnceleniyor...
# 27. Sayfa İnceleniyor...
# 28. Sayfa İnceleniyor...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-dec02ca353f2> in <cell line: 2>()
#       6   r.status_code
#       7   r.content
# ----> 8   soup = BeautifulSoup(r.content , "lxml")
#       9   urunler = soup.findAll("li" , attrs = {"class" : "productListContent-zAP0Y5msy8OHn5z7T_K_"})
#      10   link_basi = "https://www.hepsiburada.com"
#
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331             self.builder.initialize_soup(self)
#     332             try:
# --> 333                 self._feed()
#     334                 success = True
#     335                 break
#
# ...

# %%
xx
# Out:
# Empty DataFrame
# Columns: [Puan, Puana Göre Sonuç, Türkçe Yorum]
# Index: []

# %%
len(yildiz_sayisi)
# Out:
# 2366

# %%
len(yorum_listesi)
# Out:
# 2366

# %%
yildiz_sayisi.pop()
yildiz_sayisi.pop()
yildiz_sayisi.pop()
yildiz_sayisi.pop()
yildiz_sayisi.pop()
# Out:
# 3

# %%
len(yildiz_sayisi)
# Out:
# 2366

# %%
xx['Puan'] = yildiz_sayisi

# %%
xx['Türkçe Yorum'] = yorum_listesi

# %%
for i in yildiz_sayisi:
  if i == 5 or i == 4:
    sonuc.append('Pozitif')
  if i ==3:
    sonuc.append('Nötr')
  if i == 2 or i == 1:
    sonuc.append('Negatif')

# %%
xx['Puana Göre Sonuç'] = sonuc

# %%
xx
# Out:
#       Puan Puana Göre Sonuç                                       Türkçe Yorum
# 0        5          Pozitif  Anasını babasını ebesini dedesini seven bundan...
# 1        5          Pozitif  Orijinal telefon gidipte bu paralara sakın 2.e...
# 2        5          Pozitif                         Cokkkkkkk harika TV gibi🌟✨
# 3        5          Pozitif  Ürün çok güzel hiçbir sıkıntım yok sadece heps...
# 4        5          Pozitif  Pako c40 gayet iyi  memnun kaldım aldığım fiya...
# ...    ...              ...                                                ...
# 2361     2          Negatif                 Bana göre çift kamera hoş durmuyor
# 2362     5          Pozitif                      İlk izlenimim iyi sıkıntı yok
# 2363     3             Nötr                               Beğendim teşekkürler
# 2364     3             Nötr                      İlk izlenimim iyi sıkıntı yok
# 2365     5          Pozitif                               Beğendim teşekkürler
#
# [2366 rows x 3 columns]

# %%
sonuc.clear()

# %%
sonuc

# %%
xx
# Out:
#                                            Türkçe Yorum  Puan
# 0     Anasını babasını ebesini dedesini seven bundan...     5
# 1     Orijinal telefon gidipte bu paralara sakın 2.e...     5
# 2                            Cokkkkkkk harika TV gibi🌟✨     5
# 3     Ürün çok güzel hiçbir sıkıntım yok sadece heps...     5
# 4     Pako c40 gayet iyi  memnun kaldım aldığım fiya...     5
# ...                                                 ...   ...
# 2361                 Bana göre çift kamera hoş durmuyor     2
# 2362                      İlk izlenimim iyi sıkıntı yok     5
# 2363                               Beğendim teşekkürler     3
# 2364                      İlk izlenimim iyi sıkıntı yok     3
# 2365                               Beğendim teşekkürler     5
#
# [2366 rows x 2 columns]

# %%
saydir = xx[xx['Türkçe Yorum'] == 'Değerlendirilen özellikler']['Türkçe Yorum'].value_counts()

# %%
saydir
# Out:
# Değerlendirilen özellikler    54
# Name: Türkçe Yorum, dtype: int64

# %%
deneme = xx.drop(xx[xx['Türkçe Yorum'] == 'Değerlendirilen özellikler'].index)

# %%
deneme.count()
# Out:
# Puan                2312
# Puana Göre Sonuç    2312
# Türkçe Yorum        2312
# dtype: int64

# %%
deneme
# Out:
#       Puan Puana Göre Sonuç                                       Türkçe Yorum
# 0        5          Pozitif  Anasını babasını ebesini dedesini seven bundan...
# 1        5          Pozitif  Orijinal telefon gidipte bu paralara sakın 2.e...
# 2        5          Pozitif                         Cokkkkkkk harika TV gibi🌟✨
# 3        5          Pozitif  Ürün çok güzel hiçbir sıkıntım yok sadece heps...
# 4        5          Pozitif  Pako c40 gayet iyi  memnun kaldım aldığım fiya...
# ...    ...              ...                                                ...
# 2361     2          Negatif                 Bana göre çift kamera hoş durmuyor
# 2362     5          Pozitif                      İlk izlenimim iyi sıkıntı yok
# 2363     3             Nötr                               Beğendim teşekkürler
# 2364     3             Nötr                      İlk izlenimim iyi sıkıntı yok
# 2365     5          Pozitif                               Beğendim teşekkürler
#
# [2312 rows x 3 columns]

# %%
saydir
# Out:
# Değerlendirilen özellikler    57
# Name: Türkçe Yorum, dtype: int64

# %%
turkce_yorum = pd.read_csv("deneme.csv")

# %%
turkce = xx

# %%
turkce
# Out:
#       Puan Puana Göre Sonuç                                       Türkçe Yorum
# 0        5          Pozitif  Anasını babasını ebesini dedesini seven bundan...
# 1        5          Pozitif  Orijinal telefon gidipte bu paralara sakın 2.e...
# 2        5          Pozitif                         Cokkkkkkk harika TV gibi🌟✨
# 3        5          Pozitif  Ürün çok güzel hiçbir sıkıntım yok sadece heps...
# 4        5          Pozitif  Pako c40 gayet iyi  memnun kaldım aldığım fiya...
# ...    ...              ...                                                ...
# 2361     2          Negatif                 Bana göre çift kamera hoş durmuyor
# 2362     5          Pozitif                      İlk izlenimim iyi sıkıntı yok
# 2363     3             Nötr                               Beğendim teşekkürler
# 2364     3             Nötr                      İlk izlenimim iyi sıkıntı yok
# 2365     5          Pozitif                               Beğendim teşekkürler
#
# [2366 rows x 3 columns]

# %%
turkce.drop('Puan' , axis=1 , inplace = True)

# %%
turkce.drop('Puana Göre Sonuç' , axis=1 ,inplace = True)

# %%
turkce
# Out:
#                                            Türkçe Yorum
# 0     Anasını babasını ebesini dedesini seven bundan...
# 1     Orijinal telefon gidipte bu paralara sakın 2.e...
# 2                            Cokkkkkkk harika TV gibi🌟✨
# 3     Ürün çok güzel hiçbir sıkıntım yok sadece heps...
# 4     Pako c40 gayet iyi  memnun kaldım aldığım fiya...
# ...                                                 ...
# 2361                 Bana göre çift kamera hoş durmuyor
# 2362                      İlk izlenimim iyi sıkıntı yok
# 2363                               Beğendim teşekkürler
# 2364                      İlk izlenimim iyi sıkıntı yok
# 2365                               Beğendim teşekkürler
#
# [2366 rows x 1 columns]

# %%
turkce.to_csv("yorumlar-2366.csv" , index = False)

# %%
turkce_yorumlar.clear()

# %%
xx
# Out:
#                                            Türkçe Yorum
# 0     Anasını babasını ebesini dedesini seven bundan...
# 1     Orijinal telefon gidipte bu paralara sakın 2.e...
# 2                            Cokkkkkkk harika TV gibi🌟✨
# 3     Ürün çok güzel hiçbir sıkıntım yok sadece heps...
# 4     Pako c40 gayet iyi  memnun kaldım aldığım fiya...
# ...                                                 ...
# 2361                 Bana göre çift kamera hoş durmuyor
# 2362                      İlk izlenimim iyi sıkıntı yok
# 2363                               Beğendim teşekkürler
# 2364                      İlk izlenimim iyi sıkıntı yok
# 2365                               Beğendim teşekkürler
#
# [2366 rows x 1 columns]

# %%
type(xx)
# Out:
# pandas.core.frame.DataFrame

# %%
xx.to_csv("puanlı-yorumlar.csv" , index=False)

# %%
yorum_listesi.clear()

# %%
yorum_listesi
# Out:
# []

# %%
urun_listesi_df = pd.DataFrame(urun_listesi)

# %%
urun_listesi_df.to_csv("C:\\Users\\bthnb\\Masaüstü\\urun_listesi.csv" , index=False)
