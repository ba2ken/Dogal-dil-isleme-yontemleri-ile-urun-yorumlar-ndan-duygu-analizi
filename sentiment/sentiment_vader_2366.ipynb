# %%
cevrilmis = []
cevrilmis_list = []
import pandas as pd
from textblob import TextBlob

# %%
import pandas as pd
from textblob import TextBlob

# %%
vader_list = []

# %%
cevrilmis_df = pd.read_csv("cevrilmis_yorumlar-2366.csv")

# %%
cevrilmis_list = cevrilmis_df.values.tolist()

# %%
for i in range(len(cevrilmis_list)):
  listToStr = ' '.join([str(elem) for elem in cevrilmis_list[i]])
  cevrilmis.append(listToStr)

# %%
pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 4.4 MB/s eta 0:00:00
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
vader = SentimentIntensityAnalyzer()

# %%
for i in range(len(cevrilmis)):
  skor = vader.polarity_scores(cevrilmis[i])
  print(cevrilmis[i])
  print(skor)
  print("\n")
  vader_list.append(skor)

# %%
df = pd.read_csv('cevrilmis_yorumlar-2366.csv')

# %%
df.rename(columns={"Unnamed: 0": "Sıra", "0": "Yorum" } , inplace = True)

# %%
df['skor'] = df['Yorum'].apply(lambda vader_list: vader.polarity_scores(vader_list))

# %%
df.head()
# Out:
#    Sıra                                              Yorum  \
# 0     0  Those who love their parents, midwives, and gr...
# 1     1  Don't buy 2nd hand or contraband phones. big u...
# 2     2                           sokkkkkk like great tv🌟✨
# 3     3  The product is very good, I have no problems, ...
# 4     4  Pako c40 is very good, I'm satisfied, for the ...
#
#                                                 skor
# 0  {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'comp...
# 1  {'neg': 0.054, 'neu': 0.794, 'pos': 0.152, 'co...
# 2  {'neg': 0.0, 'neu': 0.31, 'pos': 0.69, 'compou...
# 3  {'neg': 0.076, 'neu': 0.759, 'pos': 0.165, 'co...
# 4  {'neg': 0.065, 'neu': 0.609, 'pos': 0.326, 'co...

# %%
df['Negatif'] = df['skor'].apply(lambda txt: txt['neg'])
df['Nötr'] = df['skor'].apply(lambda txt: txt['neu'])
df['Pozitif'] = df['skor'].apply(lambda txt: txt['pos'])
df['Sonuc'] = df['skor'].apply(lambda txt: txt['compound'])

# %%
df.head()
# Out:
#    Sıra                                              Yorum  \
# 0     0  Those who love their parents, midwives, and gr...
# 1     1  Don't buy 2nd hand or contraband phones. big u...
# 2     2                           sokkkkkk like great tv🌟✨
# 3     3  The product is very good, I have no problems, ...
# 4     4  Pako c40 is very good, I'm satisfied, for the ...
#
#                                                 skor  Negatif   Nötr  Pozitif  \
# 0  {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'comp...    0.000  0.706    0.294
# 1  {'neg': 0.054, 'neu': 0.794, 'pos': 0.152, 'co...    0.054  0.794    0.152
# 2  {'neg': 0.0, 'neu': 0.31, 'pos': 0.69, 'compou...    0.000  0.310    0.690
# 3  {'neg': 0.076, 'neu': 0.759, 'pos': 0.165, 'co...    0.076  0.759    0.165
# 4  {'neg': 0.065, 'neu': 0.609, 'pos': 0.326, 'co...    0.065  0.609    0.326
#
#     Sonuc
# 0  0.8360
# 1  0.5911
# 2  0.8360
# 3  0.4499
# 4  0.8450

# %%
def polarity_score(compound):
  if compound > 0.05:
    return "Pozitif"
  elif compound < -0.5:
    return "Negatif"
  elif compound >= -0.05 and compound < 0.05:
    return "Nötr"

# %%
df['Sentiment'] = df['Sonuc'].apply(lambda val: polarity_score(val))
df.head()
# Out:
#    Sıra                                              Yorum  \
# 0     0  Those who love their parents, midwives, and gr...
# 1     1  Don't buy 2nd hand or contraband phones. big u...
# 2     2                           sokkkkkk like great tv🌟✨
# 3     3  The product is very good, I have no problems, ...
# 4     4  Pako c40 is very good, I'm satisfied, for the ...
#
#                                                 skor  Negatif   Nötr  Pozitif  \
# 0  {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'comp...    0.000  0.706    0.294
# 1  {'neg': 0.054, 'neu': 0.794, 'pos': 0.152, 'co...    0.054  0.794    0.152
# 2  {'neg': 0.0, 'neu': 0.31, 'pos': 0.69, 'compou...    0.000  0.310    0.690
# 3  {'neg': 0.076, 'neu': 0.759, 'pos': 0.165, 'co...    0.076  0.759    0.165
# 4  {'neg': 0.065, 'neu': 0.609, 'pos': 0.326, 'co...    0.065  0.609    0.326
#
#     Sonuc Sentiment
# 0  0.8360   Pozitif
# 1  0.5911   Pozitif
# 2  0.8360   Pozitif
# 3  0.4499   Pozitif
# 4  0.8450   Pozitif

# %%
df['Sentiment'].value_counts()
# Out:
# Pozitif    1802
# Nötr        224
# Negatif     158
# Name: Sentiment, dtype: int64

# %%
df.to_csv("vader_sentiment-2366.csv")

# %%
df.head()
# Out:
#    Sıra                                              Yorum  \
# 0     0  Those who love their parents, midwives, and gr...
# 1     1  Don't buy 2nd hand or contraband phones. big u...
# 2     2                           sokkkkkk like great tv🌟✨
# 3     3  The product is very good, I have no problems, ...
# 4     4  Pako c40 is very good, I'm satisfied, for the ...
#
#                                                 skor  Negatif   Nötr  Pozitif  \
# 0  {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'comp...    0.000  0.706    0.294
# 1  {'neg': 0.054, 'neu': 0.794, 'pos': 0.152, 'co...    0.054  0.794    0.152
# 2  {'neg': 0.0, 'neu': 0.31, 'pos': 0.69, 'compou...    0.000  0.310    0.690
# 3  {'neg': 0.076, 'neu': 0.759, 'pos': 0.165, 'co...    0.076  0.759    0.165
# 4  {'neg': 0.065, 'neu': 0.609, 'pos': 0.326, 'co...    0.065  0.609    0.326
#
#     Sonuc Sentiment
# 0  0.8360   Pozitif
# 1  0.5911   Pozitif
# 2  0.8360   Pozitif
# 3  0.4499   Pozitif
# 4  0.8450   Pozitif

# %%
vader = pd.read_csv('yildizli_düzeltilmiş_çevirili_textbloblu_yorumlar-2366.csv')

# %%
vader
# Out:
#       Unnamed: 0.1  Unnamed: 0  Puan Puana Göre Sonuç  \
# 0                0           0     5          Pozitif
# 1                1           1     5          Pozitif
# 2                2           2     5          Pozitif
# 3                3           3     5          Pozitif
# 4                4           4     5          Pozitif
# ...            ...         ...   ...              ...
# 2361          2361        2361     2          Negatif
# 2362          2362        2362     5          Pozitif
# 2363          2363        2363     3             Nötr
# 2364          2364        2364     3             Nötr
# 2365          2365        2365     5          Pozitif
#
#                                            Türkçe Yorum  \
# 0     anasını babasını ebesini dedesini seven bundan...
# 1     orijinal telefon gidişte bu paralara sakın 2. ...
# 2                            çokkkkkkk harika tv gibi🌟✨
# 3     ürün çok güzel hiçbir sıkıntım yok sadece heps...
# ...

# %%
vader['Vader Sonucu'] = df['Sentiment']

# %%
vader
# Out:
#       Unnamed: 0.1  Unnamed: 0  Puan Puana Göre Sonuç  \
# 0                0           0     5          Pozitif
# 1                1           1     5          Pozitif
# 2                2           2     5          Pozitif
# 3                3           3     5          Pozitif
# 4                4           4     5          Pozitif
# ...            ...         ...   ...              ...
# 2361          2361        2361     2          Negatif
# 2362          2362        2362     5          Pozitif
# 2363          2363        2363     3             Nötr
# 2364          2364        2364     3             Nötr
# 2365          2365        2365     5          Pozitif
#
#                                            Türkçe Yorum  \
# 0     anasını babasını ebesini dedesini seven bundan...
# 1     orijinal telefon gidişte bu paralara sakın 2. ...
# 2                            çokkkkkkk harika tv gibi🌟✨
# 3     ürün çok güzel hiçbir sıkıntım yok sadece heps...
# ...

# %%
vader.insert(8, 'Vader Sentiment Skoru', df['Sonuc'])

# %%
vader
# Out:
#       Unnamed: 0.1  Unnamed: 0  Puan Puana Göre Sonuç  \
# 0                0           0     5          Pozitif
# 1                1           1     5          Pozitif
# 2                2           2     5          Pozitif
# 3                3           3     5          Pozitif
# 4                4           4     5          Pozitif
# ...            ...         ...   ...              ...
# 2361          2361        2361     2          Negatif
# 2362          2362        2362     5          Pozitif
# 2363          2363        2363     3             Nötr
# 2364          2364        2364     3             Nötr
# 2365          2365        2365     5          Pozitif
#
#                                            Türkçe Yorum  \
# 0     anasını babasını ebesini dedesini seven bundan...
# 1     orijinal telefon gidişte bu paralara sakın 2. ...
# 2                            çokkkkkkk harika tv gibi🌟✨
# 3     ürün çok güzel hiçbir sıkıntım yok sadece heps...
# ...

# %%
vader.to_csv("yildizli_düzeltilmiş_çevirili_textbloblu_vaderli_yorumlar.csv")

# %%
vader.drop('Unnamed: 0.1', axis=1, inplace=True)

# %%
vader.drop('Unnamed: 0', axis=1, inplace=True)

# %%
vader

# %%
vader.to_csv("Bitmiş-csv-2366.csv")

# %%
vader = pd.read_csv('yildizli_düzeltilmiş_çevirili_textbloblu_yorumlar-2366.csv')

# %%
vader = pd.read_csv('Bitmiş-csv-2366.csv')

# %%
xx = vader.drop(vader[vader['Vader Sonucu'] == 'NaN'].index)

# %%
yy = vader.dropna(subset=['Vader Sonucu'])

# %%
zz = yy.dropna(subset=['TextBlob Sonucu'])

# %%
zz
# Out:
#       Unnamed: 0  Puan Puana Göre Sonuç  \
# 0              0     5          Pozitif
# 1              1     5          Pozitif
# 2              2     5          Pozitif
# 3              3     5          Pozitif
# 4              4     5          Pozitif
# ...          ...   ...              ...
# 2360        2360     1          Negatif
# 2362        2362     5          Pozitif
# 2363        2363     3             Nötr
# 2364        2364     3             Nötr
# 2365        2365     5          Pozitif
#
#                                            Türkçe Yorum  \
# 0     anasını babasını ebesini dedesini seven bundan...
# 1     orijinal telefon gidişte bu paralara sakın 2. ...
# 2                            çokkkkkkk harika tv gibi🌟✨
# 3     ürün çok güzel hiçbir sıkıntım yok sadece heps...
# 4     pako c40 gayet iyi memnun kaldım aldığım fiyat...
# ...                                                 ...
# 2360  fiyat halen yüksek 32 gb çünkü 3 bin e düşerse...
# ...

# %%
zz.drop('Unnamed: 0', axis=1, inplace=True)

# %%
zz
# Out:
#       Puan Puana Göre Sonuç  \
# 0        5          Pozitif
# 1        5          Pozitif
# 2        5          Pozitif
# 3        5          Pozitif
# 4        5          Pozitif
# ...    ...              ...
# 2360     1          Negatif
# 2362     5          Pozitif
# 2363     3             Nötr
# 2364     3             Nötr
# 2365     5          Pozitif
#
#                                            Türkçe Yorum  \
# 0     anasını babasını ebesini dedesini seven bundan...
# 1     orijinal telefon gidişte bu paralara sakın 2. ...
# 2                            çokkkkkkk harika tv gibi🌟✨
# 3     ürün çok güzel hiçbir sıkıntım yok sadece heps...
# 4     pako c40 gayet iyi memnun kaldım aldığım fiyat...
# ...                                                 ...
# 2360  fiyat halen yüksek 32 gb çünkü 3 bin e düşerse...
# 2362                      ilk izlenimim iyi sıkıntı yok
# 2363                               beğendim teşekkürler
# ...

# %%
yy
# Out:
#       Unnamed: 0  Puan Puana Göre Sonuç  \
# 0              0     5          Pozitif
# 1              1     5          Pozitif
# 2              2     5          Pozitif
# 3              3     5          Pozitif
# 4              4     5          Pozitif
# ...          ...   ...              ...
# 2360        2360     1          Negatif
# 2362        2362     5          Pozitif
# 2363        2363     3             Nötr
# 2364        2364     3             Nötr
# 2365        2365     5          Pozitif
#
#                                            Türkçe Yorum  \
# 0     anasını babasını ebesini dedesini seven bundan...
# 1     orijinal telefon gidişte bu paralara sakın 2. ...
# 2                            çokkkkkkk harika tv gibi🌟✨
# 3     ürün çok güzel hiçbir sıkıntım yok sadece heps...
# 4     pako c40 gayet iyi memnun kaldım aldığım fiyat...
# ...                                                 ...
# 2360  fiyat halen yüksek 32 gb çünkü 3 bin e düşerse...
# ...

# %%
yy['Vader Sonucu'].value_counts()
# Out:
# Pozitif    1802
# Nötr        224
# Negatif     158
# Name: Vader Sonucu, dtype: int64

# %%
vader['TextBlob Sonucu'].value_counts()
# Out:
# Pozitif    1884
# Negatif     243
# Nötr        239
# Name: TextBlob Sonucu, dtype: int64

# %%
df = df.drop(df[df['column_name'] == 'belirli_deger'].index)

# %%
vader["Vader Sonucu"]
# Out:
# 0       Pozitif
# 1       Pozitif
# 2       Pozitif
# 3       Pozitif
# 4       Pozitif
#          ...
# 2361        NaN
# 2362    Pozitif
# 2363    Pozitif
# 2364    Pozitif
# 2365    Pozitif
# Name: Vader Sonucu, Length: 2366, dtype: object

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
vader['Vader Sonucu']=vader['Vader Sonucu'].astype('str')

# %%
print(classification_report(zz['Puana Göre Sonuç'],zz['Vader Sonucu']))
# Out:
#               precision    recall  f1-score   support
#
#      Negatif       0.18      0.11      0.13       261
#         Nötr       0.07      0.15      0.10       105
#      Pozitif       0.84      0.84      0.84      1818
#
#     accuracy                           0.72      2184
#    macro avg       0.36      0.37      0.36      2184
# weighted avg       0.73      0.72      0.72      2184

# %%
skor_tutarlilik = accuracy_score(zz['Puana Göre Sonuç'], zz['Vader Sonucu'])
print("Tutarlılık: {}\n".format(skor_tutarlilik))
# Out:
# Tutarlılık: 0.7156593406593407

# %%
print(classification_report(zz['Puana Göre Sonuç'],zz['TextBlob Sonucu']))
# Out:
#               precision    recall  f1-score   support
#
#      Negatif       0.16      0.11      0.13       261
#         Nötr       0.06      0.12      0.08       105
#      Pozitif       0.84      0.82      0.83      1818
#
#     accuracy                           0.71      2184
#    macro avg       0.35      0.35      0.35      2184
# weighted avg       0.72      0.71      0.71      2184

# %%
skor_tutarlilik = accuracy_score(zz['Puana Göre Sonuç'], zz['TextBlob Sonucu'])
print("Tutarlılık: {}\n".format(skor_tutarlilik))
# Out:
# Tutarlılık: 0.7051282051282052

# %%
print(classification_report(zz['TextBlob Sonucu'],zz['Vader Sonucu']))
# Out:
#               precision    recall  f1-score   support
#
#      Negatif       0.54      0.45      0.49       187
#         Nötr       0.60      0.63      0.61       214
#      Pozitif       0.93      0.94      0.93      1783
#
#     accuracy                           0.86      2184
#    macro avg       0.69      0.67      0.68      2184
# weighted avg       0.86      0.86      0.86      2184

# %%
skor_tutarlilik = accuracy_score(zz['Vader Sonucu'], zz['TextBlob Sonucu'])
print("Tutarlılık: {}\n".format(skor_tutarlilik))
# Out:
# Tutarlılık: 0.8644688644688645

# %%
bittibitikler = pd.read_csv('sonbitiş.csv')

# %%
bittibitikler
# Out:
#      Unnamed: 0.1  Unnamed: 0  Puan Puana Göre Sonuç  \
# 0               0           0     5          Pozitif
# 1               1           1     5          Pozitif
# 2               2           2     5          Pozitif
# 3               3           3     5          Pozitif
# 4               4           4     5          Pozitif
# ..            ...         ...   ...              ...
# 824           824         824     5          Pozitif
# 825           825         825     5          Pozitif
# 826           826         826     3             Nötr
# 827           827         827     5          Pozitif
# 828           828         828     5          Pozitif
#
#                                           Türkçe Yorum  \
# 0    anasını babasını ebesini dedesini seven bundan...
# 1    orijinal telefon gidişte bu paralara sakın 2. ...
# 2                           çokkkkkkk harika tv gibi🌟✨
# 3    ürün çok güzel hiçbir sıkıntım yok sadece heps...
# ...

# %%
bittibitikler.drop('Unnamed: 0.1', axis=1, inplace=True)

# %%
bittibitikler.drop('Unnamed: 0', axis=1, inplace=True)

# %%
bittibitikler.insert(6, 'Vader Sentiment Skoru', df['Sonuc'])

# %%
bittibitikler
# Out:
#      Puan Puana Göre Sonuç                                       Türkçe Yorum  \
# 0       5          Pozitif  anasını babasını ebesini dedesini seven bundan...
# 1       5          Pozitif  orijinal telefon gidişte bu paralara sakın 2. ...
# 2       5          Pozitif                         çokkkkkkk harika tv gibi🌟✨
# 3       5          Pozitif  ürün çok güzel hiçbir sıkıntım yok sadece heps...
# 4       5          Pozitif  pako c40 gayet iyi memnun kaldım aldığım fiyat...
# ..    ...              ...                                                ...
# 824     5          Pozitif  piyasada bu boyutlarda bu kadar özellikli ve h...
# 825     5          Pozitif  2 haftalık kullanım sonrası değerlendirme ; 1 ...
# 826     3             Nötr  çok uzun yıllardır ilk kez bir ıphone aldım . ...
# 827     5          Pozitif  2 yıldır ıphone 11 pro max kullanıyorum , ne c...
# 828     5          Pozitif  cihazın en önemli artısı boyutları . bu cihaz ...
#
# ...

# %%
bittibitikler.to_csv("Bitti.csv")

# %%
bittibitikler['Vader Sonucu'] = bittibitikler['Vader Sonucu'].str.title()

# %%
bittibitikler
# Out:
#      Puan Puana Göre Sonuç                                       Türkçe Yorum  \
# 0       5          Pozitif  anasını babasını ebesini dedesini seven bundan...
# 1       5          Pozitif  orijinal telefon gidişte bu paralara sakın 2. ...
# 2       5          Pozitif                         çokkkkkkk harika tv gibi🌟✨
# 3       5          Pozitif  ürün çok güzel hiçbir sıkıntım yok sadece heps...
# 4       5          Pozitif  pako c40 gayet iyi memnun kaldım aldığım fiyat...
# ..    ...              ...                                                ...
# 824     5          Pozitif  piyasada bu boyutlarda bu kadar özellikli ve h...
# 825     5          Pozitif  2 haftalık kullanım sonrası değerlendirme ; 1 ...
# 826     3             Nötr  çok uzun yıllardır ilk kez bir ıphone aldım . ...
# 827     5          Pozitif  2 yıldır ıphone 11 pro max kullanıyorum , ne c...
# 828     5          Pozitif  cihazın en önemli artısı boyutları . bu cihaz ...
#
# ...

# %%
bittibitikler['Vader Sonucu']

# %%
bittibitikler['Vader Sonucu']
# Out:
# 0      Pozitif
# 1      Pozitif
# 2      Pozitif
# 3      Pozitif
# 4      Pozitif
#         ...
# 824    Pozitif
# 825    Pozitif
# 826    Negatif
# 827    Pozitif
# 828    Pozitif
# Name: Vader Sonucu, Length: 829, dtype: object

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
bittibitikler['Vader Sonucu']=bittibitikler['Vader Sonucu'].astype('str')

# %%
print(classification_report(bittibitikler['Puana Göre Sonuç'],bittibitikler['Vader Sonucu']))
# Out:
#               precision    recall  f1-score   support
#
#      Negatif       0.34      0.19      0.24       124
#         Nötr       0.06      0.11      0.08        35
#      Pozitif       0.85      0.80      0.82       670
#          nan       0.00      0.00      0.00         0
#
#     accuracy                           0.68       829
#    macro avg       0.31      0.27      0.29       829
# weighted avg       0.74      0.68      0.71       829
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
skor_tutarlilik = accuracy_score(bittibitikler['Puana Göre Sonuç'], bittibitikler['Vader Sonucu'])
print("Tutarlılık: {}\n".format(skor_tutarlilik))
# Out:
# Tutarlılık: 0.6791314837153196

# %%
print(classification_report(bittibitikler['TextBlob Sonucu'],bittibitikler['Vader Sonucu']))
# Out:
#               precision    recall  f1-score   support
#
#      Negatif       0.58      0.39      0.47        99
#         Nötr       0.46      0.41      0.44        75
#      Pozitif       0.92      0.88      0.90       655
#          nan       0.00      0.00      0.00         0
#
#     accuracy                           0.78       829
#    macro avg       0.49      0.42      0.45       829
# weighted avg       0.84      0.78      0.81       829
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print(classification_report(bittibitikler['Vader Sonucu'],bittibitikler['TextBlob Sonucu']))
# Out:
#               precision    recall  f1-score   support
#
#      Negatif       0.39      0.58      0.47        67
#         Nötr       0.41      0.46      0.44        67
#      Pozitif       0.88      0.92      0.90       630
#          nan       0.00      0.00      0.00        65
#
#     accuracy                           0.78       829
#    macro avg       0.42      0.49      0.45       829
# weighted avg       0.74      0.78      0.76       829
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
skor_tutarlilik = accuracy_score(bittibitikler['Vader Sonucu'], bittibitikler['TextBlob Sonucu'])
print("Tutarlılık: {}\n".format(skor_tutarlilik))
# Out:
# Tutarlılık: 0.781664656212304

# %%
bittibitikler
